# %%
from summarytools import dfSummary

# %%
import pandas as pd

# %%
df = pd.read_csv('entsorgungsstatistik-stadt-stgallen.csv', sep = ';')
df.head()
# Out:
#   Monat_Jahr Abfallfraktion Unterkategorie Entsorgungsart Abfuhrgebiet  \
# 0    2015-04       Kehricht            NaN            NaN          NaN
# 1    2016-02       Kehricht            NaN            NaN          NaN
# 2    2016-06       Kehricht            NaN            NaN          NaN
# 3    2016-08       Kehricht            NaN            NaN          NaN
# 4    2017-11       Kehricht            NaN            NaN          NaN
#
#   Annahmestelle Deponie Anlieferung  Gewicht in kg  Gewicht in t
# 0           NaN                 NaN      1434100.0       1434.10
# 1           NaN                 NaN      1335040.0       1335.04
# 2           NaN                 NaN      1494690.0       1494.69
# 3           NaN                 NaN      1374210.0       1374.21
# 4           NaN                 NaN      1363680.0       1363.68

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_c7716 thead>tr>th {
#   text-align: left;
# }
# #T_c7716_row0_col0, #T_c7716_row1_col0, #T_c7716_row2_col0, #T_c7716_row3_col0, #T_c7716_row4_col0, #T_c7716_row5_col0, #T_c7716_row6_col0, #T_c7716_row7_col0, #T_c7716_row8_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_c7716_row0_col1, #T_c7716_row1_col1, #T_c7716_row2_col1, #T_c7716_row3_col1, #T_c7716_row4_col1, #T_c7716_row5_col1, #T_c7716_row6_col1, #T_c7716_row7_col1, #T_c7716_row8_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_c7716_row0_col2, #T_c7716_row1_col2, #T_c7716_row2_col2, #T_c7716_row3_col2, #T_c7716_row4_col2, #T_c7716_row5_col2, #T_c7716_row6_col2, #T_c7716_row7_col2, #T_c7716_row8_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_c7716_row0_col3, #T_c7716_row1_col3, #T_c7716_row2_col3, #T_c7716_row3_col3, #T_c7716_row4_col3, #T_c7716_row5_col3, #T_c7716_row6_col3, #T_c7716_row7_col3, #T_c7716_row8_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_c7716_row0_col4, #T_c7716_row1_col4, #T_c7716_row2_col4, #T_c7716_row3_col4, #T_c7716_row4_col4, #T_c7716_row5_col4, #T_c7716_row6_col4, #T_c7716_row7_col4, #T_c7716_row8_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_c7716_row0_col5, #T_c7716_row1_col5, #T_c7716_row2_col5, #T_c7716_row3_col5, #T_c7716_row4_col5, #T_c7716_row5_col5, #T_c7716_row6_col5, #T_c7716_row7_col5, #T_c7716_row8_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_c7716">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 5,165 x 9<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_c7716_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_c7716_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_c7716_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_c7716_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_c7716_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_c7716_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c7716_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c7716_row0_col1" class="data row0 col1" ><strong>Monat_Jahr</strong><br>[object]</td>
#       <td id="T_c7716_row0_col2" class="data row0 col2" >1. 2022-04<br>2. 2022-09<br>3. 2022-06<br>4. 2022-03<br>5. 2022-01<br>6. 2022-12<br>7. 2022-02<br>8. 2022-05<br>9. 2022-08<br>10. 2022-11<br>11. other</td>
#       <td id="T_c7716_row0_col3" class="data row0 col3" >125 (2.4%)<br>104 (2.0%)<br>103 (2.0%)<br>103 (2.0%)<br>100 (1.9%)<br>96 (1.9%)<br>96 (1.9%)<br>94 (1.8%)<br>89 (1.7%)<br>82 (1.6%)<br>4,173 (80.8%)</td>
#       <td id="T_c7716_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_c7716_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_c7716_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_c7716_row1_col1" class="data row1 col1" ><strong>Abfallfraktion</strong><br>[object]</td>
#       <td id="T_c7716_row1_col2" class="data row1 col2" >1. Papier<br>2. Karton<br>3. Sonderabfall<br>4. Altmetall<br>5. Grüngut<br>6. Glas<br>7. Kehricht<br>8. Dosen<br>9. Altöl</td>
#       <td id="T_c7716_row1_col3" class="data row1 col3" >1,797 (34.8%)<br>1,481 (28.7%)<br>1,105 (21.4%)<br>223 (4.3%)<br>146 (2.8%)<br>123 (2.4%)<br>97 (1.9%)<br>97 (1.9%)<br>96 (1.9%)</td>
#       <td id="T_c7716_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_c7716_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_c7716_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_c7716_row2_col1" class="data row2 col1" ><strong>Unterkategorie</strong><br>[object]</td>
#       <td id="T_c7716_row2_col2" class="data row2 col2" >1. nan<br>2. Chemikalien<br>3. Altmedikamente<br>4. Spraydosen<br>5. Pestizide<br>6. Lösungsmittel<br>7. Hg Bruch<br>8. Farben wässrig<br>9. Wässrige Lösung<br>10. Säuren<br>11. other</td>
#       <td id="T_c7716_row2_col3" class="data row2 col3" >4,021 (77.9%)<br>97 (1.9%)<br>97 (1.9%)<br>94 (1.8%)<br>94 (1.8%)<br>94 (1.8%)<br>92 (1.8%)<br>92 (1.8%)<br>90 (1.7%)<br>89 (1.7%)<br>305 (5.9%)</td>
#       <td id="T_c7716_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_c7716_row2_col5" class="data row2 col5" >4,021<br>(77.9%)</td>
#     </tr>
#     <tr>
#       <td id="T_c7716_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_c7716_row3_col1" class="data row3 col1" ><strong>Entsorgungsart</strong><br>[object]</td>
#       <td id="T_c7716_row3_col2" class="data row3 col2" >1. Strassensammlung<br>2. Annahmestelle<br>3. nan</td>
#       <td id="T_c7716_row3_col3" class="data row3 col3" >2,658 (51.5%)<br>2,410 (46.7%)<br>97 (1.9%)</td>
#       <td id="T_c7716_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_c7716_row3_col5" class="data row3 col5" >97<br>(1.9%)</td>
#     </tr>
#     <tr>
#       <td id="T_c7716_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_c7716_row4_col1" class="data row4 col1" ><strong>Abfuhrgebiet</strong><br>[object]</td>
#       <td id="T_c7716_row4_col2" class="data row4 col2" >1. nan<br>2. I<br>3. K<br>4. B<br>5. F<br>6. H<br>7. D<br>8. A<br>9. G<br>10. C<br>11. other</td>
#       <td id="T_c7716_row4_col3" class="data row4 col3" >3,116 (60.3%)<br>183 (3.5%)<br>183 (3.5%)<br>183 (3.5%)<br>183 (3.5%)<br>183 (3.5%)<br>183 (3.5%)<br>183 (3.5%)<br>182 (3.5%)<br>182 (3.5%)<br>404 (7.8%)</td>
#       <td id="T_c7716_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_c7716_row4_col5" class="data row4 col5" >3,116<br>(60.3%)</td>
#     </tr>
#     <tr>
#       <td id="T_c7716_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_c7716_row5_col1" class="data row5 col1" ><strong>Annahmestelle</strong><br>[object]</td>
#       <td id="T_c7716_row5_col2" class="data row5 col2" >1. nan<br>2. Apotheken / Drogerien<br>3. Sammelstellen<br>4. RE West<br>5. RE Ost<br>6. Deponie Tüfentobel<br>7. Werkhof Wiedacker<br>8. Werkhof Waldau</td>
#       <td id="T_c7716_row5_col3" class="data row5 col3" >2,755 (53.3%)<br>1,105 (21.4%)<br>400 (7.7%)<br>388 (7.5%)<br>382 (7.4%)<br>73 (1.4%)<br>47 (0.9%)<br>15 (0.3%)</td>
#       <td id="T_c7716_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_c7716_row5_col5" class="data row5 col5" >2,755<br>(53.3%)</td>
#     </tr>
#     <tr>
#       <td id="T_c7716_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_c7716_row6_col1" class="data row6 col1" ><strong>Deponie Anlieferung</strong><br>[object]</td>
#       <td id="T_c7716_row6_col2" class="data row6 col2" >1. nan<br>2. Privatanlieferer</td>
#       <td id="T_c7716_row6_col3" class="data row6 col3" >5,092 (98.6%)<br>73 (1.4%)</td>
#       <td id="T_c7716_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_c7716_row6_col5" class="data row6 col5" >5,092<br>(98.6%)</td>
#     </tr>
#     <tr>
#       <td id="T_c7716_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_c7716_row7_col1" class="data row7 col1" ><strong>Gewicht in kg</strong><br>[float64]</td>
#       <td id="T_c7716_row7_col2" class="data row7 col2" >Mean (sd) : 38046.7 (183034.2)<br>min < med < max:<br>0.0 < 5610.0 < 1551100.0<br>IQR (CV) : 10780.0 (0.2)</td>
#       <td id="T_c7716_row7_col3" class="data row7 col3" >2,315 distinct values</td>
#       <td id="T_c7716_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_c7716_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>

# %%
from skimpy import skim

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 5165   │ │ string      │ 7     │                                                          │
# │ │ Number of columns │ 9      │ │ float64     │ 2     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column_name         ┃ NA   ┃ NA %   ┃ mean     ┃ sd        ┃ p0   ┃ p25    ┃ p75     ┃ p100      ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━┩  │
# │ │ Gewicht in kg       │    0 │      0 │    38000 │    180000 │    0 │   1100 │   12000 │   1600000 │    █    │  │
# │ │ Gewicht in t        │    0 │      0 │       38 │       180 │    0 │    1.1 │      12 │      1600 │    █    │  │
# │ └─────────────────────┴──────┴────────┴──────────┴───────────┴──────┴────────┴─────────┴───────────┴─────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                        ┃ NA        ┃ NA %      ┃ words per row           ┃ total words         ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ Monat_Jahr                         │         0 │         0 │                       1 │                5200 │  │
# │ │ Abfallfraktion                     │         0 │         0 │                       1 │                5200 │  │
# │ │ Unterkategorie                     │      4000 │        78 │                       1 │                5200 │  │
# │ │ Entsorgungsart                     │        97 │       1.9 │                       1 │                5200 │  │
# │ │ Abfuhrgebiet                       │      3100 │        60 │                       1 │                5200 │  │
# │ │ Annahmestelle                      │      2800 │        53 │                       1 │                5200 │  │
# │ │ Deponie Anlieferung                │      5100 │        99 │                       1 │                5200 │  │
# │ └────────────────────────────────────┴───────────┴───────────┴─────────────────────────┴─────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯
